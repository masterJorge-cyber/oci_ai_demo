# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# Carregar o dataset Iris
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Series(iris.target)

# Mapear os rótulos numéricos para nomes de espécies para melhor legibilidade
target_names = iris.target_names
y_named = y.map(lambda x: target_names[x])# Convertendo os rótulos numéricos para nomes de espécies

print("Primeiras 5 linhas do dataset Iris (features):")
print(X.head())
print("\nPrimeiras 5 linhas do dataset Iris (target - espécies):")
print(y_named.head())

# Dividir os dados em conjuntos de treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y_named, test_size=0.2, random_state=42)

print(f"\nTamanho do conjunto de treino: {len(X_train)} amostras")
print(f"Tamanho do conjunto de teste: {len(X_test)} amostras")
# Out:
# Primeiras 5 linhas do dataset Iris (features):
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Primeiras 5 linhas do dataset Iris (target - espécies):
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# dtype: object
#
# Tamanho do conjunto de treino: 120 amostras
# Tamanho do conjunto de teste: 30 amostras

# %%
import automlx as automlx
from automlx import init 
from automlx import AutoClassifier  

automl = AutoClassifier()  # Desativa paralelismo
# O método .fit() inicia o processo de busca do melhor modelo

#est1 = automlx.Pipeline(task = 'classification', model_list=['DecisionTreeClassifier']) # Cria um pipeline de automação de machine learning para classificação
model = automl.fit(X_train, y_train) # Treina o modelo com os dados de treino
# Out:
# [2025-08-06 01:22:49,286] [automlx.backend] Overwriting ray session directory to C:/Users/JORGEB~1/AppData/Local/Temp/bsl4hj3_\ray, which will be deleted at engine shutdown. If you wish to retain ray logs, provide _temp_dir in ray_setup dict of engine_opts when initializing the AutoMLx engine.
# [2025-08-06 01:23:03,919] [automlx.interface] Dataset shape: (120,4)
# [2025-08-06 01:23:04,385] [automlx.data_transform] Running preprocessing. Number of features: 5
# [2025-08-06 01:23:05,026] [automlx.data_transform] Preprocessing completed. Took 0.642 secs
# [2025-08-06 01:23:05,089] [automlx.process] Running Model Generation
# [2025-08-06 01:23:05,224] [automlx] Provided model (TorchMLPClassifier) is not supported.Supported models are: ['CatBoostClassifier', 'LGBMClassifier', 'SVC', 'AdaBoostClassifier', 'DecisionTreeClassifier', 'ExtraTreesClassifier', 'GaussianNB', 'GradientBoostingClassifier', 'KNeighborsClassifier', 'LinearSVC', 'LogisticRegressionClassifier', 'RandomForestClassifier', 'XGBClassifier']
# [2025-08-06 01:23:05,230] [automlx.process] Model Generation completed.
# [2025-08-06 01:23:05,500] [automlx.model_selection] Running Model Selection
# (run pid=17640) [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000017 seconds.
# (run pid=17640) You can set `force_row_wise=true` to remove the overhead.
# (run pid=17640) And if memory is not enough, you can set `force_col_wise=true`.
# (run pid=17640) [LightGBM] [Info] Total Bins 83
# (run pid=17640) [LightGBM] [Info] Number of data points in the train set: 96, number of used features: 4
# (run pid=17640) [LightGBM] [Info] Start training from score -1.099264
# (run pid=17640) [LightGBM] [Info] Start training from score -1.130035
# (run pid=17640) [LightGBM] [Info] Start training from score -1.067515
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=17640) [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# (run pid=5900) [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000045 seconds.
# (run pid=5900) You can set `force_col_wise=true` to remove the overhead.
# (run pid=17640)
# [2025-08-06 01:23:37,476] [automlx.model_selection] Model Selection completed - Took 31.976 sec - Selected models: [['ExtraTreesClassifier']]
# [2025-08-06 01:23:37,528] [automlx.adaptive_sampling] Running Adaptive Sampling. Dataset shape: (120,5).
# [2025-08-06 01:23:37,543] [automlx.adaptive_sampling] Adaptive Sampling: top_limit: 33 < bottom_limit: 1000,
# sampling process will be skipped
# [2025-08-06 01:23:37,546] [automlx.adaptive_sampling] Adaptive Sampling: top_limit: 9 < bottom_limit: 1000,
# sampling process will be skipped
# [2025-08-06 01:23:37,666] [automlx.feature_selection] Starting feature ranking for ExtraTreesClassifier
# [2025-08-06 01:23:41,444] [automlx.feature_selection] Feature Selection completed. Took 3.795 secs.
# [2025-08-06 01:23:41,495] [automlx.trials] Running Model Tuning for ['ExtraTreesClassifier']
# [2025-08-06 01:24:09,075] [automlx.trials] Best parameters for ExtraTreesClassifier: {'n_estimators': 100, 'min_samples_split': 0.0169655625, 'min_samples_leaf': 0.000625, 'max_features': 0.777777778, 'class_weight': 'balanced', 'criterion': 'entropy'}
# [2025-08-06 01:24:09,077] [automlx.trials] Model Tuning completed. Took: 27.582 secs
# [2025-08-06 01:24:12,557] [automlx.interface] Re-fitting pipeline
# [2025-08-06 01:24:12,571] [automlx.final_fit] Skipping updating parameter seed, already fixed by FinalFit_40375024-9
# [2025-08-06 01:24:14,201] [automlx.interface] AutoMLx completed.

# %%
automl.completed_trials_summary_
# Exibe o resumo dos trials concluídos
# Out:
#                Step                            # Samples  # Features  \
# 0   Model Selection  {2: 96, 3: 96, 1: 96, 4: 96, 5: 96}           4
# 1   Model Selection  {1: 96, 3: 96, 2: 96, 4: 96, 5: 96}           4
# 2   Model Selection  {1: 96, 2: 96, 3: 96, 4: 96, 5: 96}           4
# 3   Model Selection  {1: 96, 2: 96, 3: 96, 4: 96, 5: 96}           4
# 4   Model Selection  {2: 96, 3: 96, 1: 96, 4: 96, 5: 96}           4
# ..              ...                                  ...         ...
# 84     Model Tuning  {1: 96, 2: 96, 3: 96, 4: 96, 5: 96}           3
# 85     Model Tuning  {1: 96, 2: 96, 4: 96, 5: 96, 3: 96}           3
# 86     Model Tuning  {1: 96, 2: 96, 3: 96, 4: 96, 5: 96}           3
# 87     Model Tuning  {1: 96, 2: 96, 3: 96, 4: 96, 5: 96}           3
# 88     Model Tuning  {1: 96, 2: 96, 3: 96, 4: 96, 5: 96}           3
#
#                  Algorithm                                    Hyperparameters  \
# 0     ExtraTreesClassifier  {'n_estimators': 100, 'min_samples_split': 0.0...
# 1   RandomForestClassifier  {'n_estimators': 100, 'min_samples_split': 0.0...
# 2               GaussianNB                                                 {}
# 3           LGBMClassifier  {'num_leaves': 31, 'boosting_type': 'gbdt', 'l...
# 4            XGBClassifier  {'learning_rate': 0.1, 'min_child_weight': 1, ...
# ..                     ...                                                ...
# 84    ExtraTreesClassifier  {'n_estimators': 5, 'min_samples_split': 0.016...
# 85    ExtraTreesClassifier  {'n_estimators': 5, 'min_samples_split': 0.016...
# 86    ExtraTreesClassifier  {'n_estimators': 5, 'min_samples_split': 0.016...
# 87    ExtraTreesClassifier  {'n_estimators': 5, 'min_samples_split': 0.016...
# 88    ExtraTreesClassifier  {'n_estimators': 5, 'min_samples_split': 0.016...
#
#    Score (neg_log_loss)                             All Metrics  \
# 0             -0.127043  {'neg_log_loss': -0.12704327046293135}
# 1             -0.129726    {'neg_log_loss': -0.129725593846674}
# 2             -0.157324  {'neg_log_loss': -0.15732372273410994}
# 3             -0.206399  {'neg_log_loss': -0.20639932361964028}
# 4             -0.214263  {'neg_log_loss': -0.21426286315567927}
# ..                  ...                                     ...
# 84            -0.977488    {'neg_log_loss': -0.977487920283312}
# 85            -0.977488    {'neg_log_loss': -0.977487920283312}
# 86            -0.977488    {'neg_log_loss': -0.977487920283312}
# 87            -0.977488    {'neg_log_loss': -0.977487920283312}
# 88            -0.977488    {'neg_log_loss': -0.977487920283312}
#
#     Runtime (Seconds)  Memory Usage (GB)                  Finished
# 0            2.052848           0.253235  Wed Aug  6 01:23:35 2025
# 1            1.786854           0.268169  Wed Aug  6 01:23:36 2025
# 2            0.404543           0.253239  Wed Aug  6 01:23:35 2025
# 3            2.581278           0.268963  Wed Aug  6 01:23:35 2025
# 4            1.080963           0.281944  Wed Aug  6 01:23:37 2025
# ..                ...                ...                       ...
# 84           1.098977           0.283230  Wed Aug  6 01:23:57 2025
# 85           0.800039           0.283112  Wed Aug  6 01:23:51 2025
# 86           0.851588           0.283123  Wed Aug  6 01:23:52 2025
# 87           0.753049           0.282269  Wed Aug  6 01:23:52 2025
# 88           0.776068           0.283138  Wed Aug  6 01:23:52 2025
#
# [89 rows x 10 columns]

# %%
automl.selected_model_
# Out:
# 'ExtraTreesClassifier'

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

labels = y_named.unique().tolist()
# Faz previsões com o modelo treinado
y_pred = model.predict(X_test)

# Gera a matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Exibe a matriz de confusão
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)
plt.xticks(rotation=45)
plt.title("Matriz de Confusão - AutoMLx")
plt.show()

# %%
colunas = X_train.columns
novo_exemplo_df = pd.DataFrame([[5.4, 3.9, 1.3, 2.4]], columns=colunas)
predito = automl.predict(novo_exemplo_df)[0]
print(f"Classe prevista para [130.9, 3.0, 5.1, 1.9]: {predito}") #5.4,3.9,1.3,0.4
# Out:
# Classe prevista para [130.9, 3.0, 5.1, 1.9]: virginica
